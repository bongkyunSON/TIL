# %%
import os
import pandas as pd
import numpy as np
from math import sqrt
from tqdm import tqdm_notebook as tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import matplotlib.font_manager as fm
import matplotlib
import itertools

# %%
fm.get_fontconfig_fonts()
font_location = 'C:\\WINDOWS\\Fonts\\malgun.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)
# Out:
# C:\Users\bongkyun\AppData\Local\Temp\ipykernel_11740\2582751676.py:1: MatplotlibDeprecationWarning:
# The get_fontconfig_fonts function was deprecated in Matplotlib 3.5 and will be removed two minor releases later.
#   fm.get_fontconfig_fonts()

# %%
FILES_DIR = '../data/a1/'
log_df = pd.read_csv(FILES_DIR + 'log_csv.csv')

# %%
# null값들을 un_** 으로 채워서 확인해보기
log_drop_null = log_df
log_drop_null['geoip_city_name'].fillna('un_city_name', inplace = True)
log_drop_null['category3'].fillna('un_category', inplace = True)
log_drop_null['uid'].fillna('un_name', inplace = True)
log_drop_null.dropna(axis = 0, inplace = True)
print(log_drop_null.isnull().sum().sort_values(ascending=False)) # null값 퍼센트로 표현
# Out:
# Unnamed: 0         0
# uid                0
# action_type        0
# category1          0
# category2          0
# category3          0
# collect_time       0
# geoip_city_name    0
# useragent_os       0
# viewrate           0
# viewtime           0
# rating             0
# dtype: int64

# %%
log_drop_null['rating'] = log_drop_null['action_type']
re_name = {'rating' : {'View':1, 'Highlight':2, 'Basket':4, 'Copy':3, 'SINF':0}}
log_drop_null = log_drop_null.replace(re_name)
log_drop_null = log_drop_null[['uid', 'category2', 'rating']]
log_drop_null
# Out:
#                       uid  category2  rating
# 0        avpKyWMn/xEADNlb     그릇·홈세트       1
# 1        0+5vEmGkOuAAB5j2         매트       4
# 2        r8DXy2OtSl8AAojG     커튼·부자재       1
# 3        dC9Fl2Ly9lcADrTn     플라워·식물       2
# 4        09gKcGLg0I8ACyQy     진열장·책장       1
# ...                   ...        ...     ...
# 5659536  PUpxWWMWdcIACR2B     칼·커팅기구       1
# 5659537  PVMstmNg4I4ADq9R     진열장·책장       4
# 5659538  diRXdmN49dUABrVo  테이블·식탁·책상       1
# 5659539  dusFzWJvp5cADhZW       계절가전       1
# 5659540  bgy5ZGOszc4ADrmd     화장대·콘솔       1
#
# [5657112 rows x 3 columns]

# %%
log = log_drop_null.drop_duplicates()
log
# Out:
#                       uid category2  rating
# 0        avpKyWMn/xEADNlb    그릇·홈세트       1
# 1        0+5vEmGkOuAAB5j2        매트       4
# 2        r8DXy2OtSl8AAojG    커튼·부자재       1
# 3        dC9Fl2Ly9lcADrTn    플라워·식물       2
# 4        09gKcGLg0I8ACyQy    진열장·책장       1
# ...                   ...       ...     ...
# 5659504  eiIedGNsz7MAC4Wi        선반       1
# 5659515  AeCSamOsMCsACJDD       옷걸이       1
# 5659530  0rIeEmOs/WwABY+T    수납장·옷장       1
# 5659536  PUpxWWMWdcIACR2B    칼·커팅기구       1
# 5659540  bgy5ZGOszc4ADrmd    화장대·콘솔       1
#
# [1760873 rows x 3 columns]

# %%
log['uid'].nunique()
# Out:
# 828075

# %%
log_sample = log.sample(frac=0.01, random_state=42)
log_sample = log_sample.drop_duplicates()
log_sample['uid'].nunique()
# Out:
# 16867

# %%
log_sample
# Out:
#                       uid  category2  rating
# 2905050  3HSqnWOmn7oADJH4  테이블·식탁·책상       1
# 5267375  AdbYGmI78zwABqxk   리빙박스·바구니       1
# 274023   3Z1LXGOQI+4ACHnS         매트       1
# 673227   2p4mBGGl+OgACASX     가벽·파티션       1
# 1888515  amWBqWOoOccABzk1       욕실용품       1
# ...                   ...        ...     ...
# 5636345  cKrDh2Otlu8ADAqe         침대       1
# 1622670  0yzXAmOgAB4AAD/h    생활·건강가전       1
# 1146452  fbkZ4GFY1f8AC9u4  화장대·테이블정리       1
# 2474365  DjNnamGfMSsAAdr4     이불·이불솜       1
# 2766716  M8Yzm2H7pNMABE4u     디퓨저·캔들       1
#
# [17609 rows x 3 columns]

# %%
train_df, test_df = train_test_split(log, test_size=0.2, random_state=42)

print(train_df.shape)
print(test_df.shape)
# Out:
# (1408698, 3)
# (352175, 3)

# %%
train_df = train_df.drop_duplicates()
train_df['category2'].unique()
# Out:
# array(['소파', '홈패브릭', '그릇·홈세트', '거실장·TV장', '꾸미기팁', '매트리스·토퍼', '컵·잔·텀블러',
#        '서랍·수납장', '매트·안전용품', '침대', '파티·완구', '플라워·식물', '생활·건강가전', '청소기',
#        '베개·베개커버', '수납장·옷장', '매트', '보관·용기·도시락', '시공정보', '테이블·식탁·책상',
#        '계절가전', '러그·카페트', '의자', '이불·이불솜', '안전·방범용품', '커튼·부자재', '토퍼·패드',
#        '디퓨저·캔들', '진열장·책장', '주방수납·정리', '무드등·장식조명', '홈갤러리', '화장대·콘솔',
#        '스킨케어', '장스탠드', '수도', '옷정리·이불정리', '냉동·냉장·간편식', '주방잡화', '주방패브릭',
#        '야외가구', '리빙박스·바구니', '데스크·디자인문구', '생활정보', '인테리어소품', '선반', '반찬·장류',
#        '강아지', '지식백과', '공간별수납정리', '가구', '주방가전', '전기', 'O!SelectShop',
#        '크리스마스', '청소용품', '스킨케어·목욕용품', '수납', '음향가전', '세탁·세제용품', '커피·티용품',
#        '바디케어', '수저·커트러리', '행거·옷장', '생활잡화', '벽지·시트지', '거울', '게임기·드론',
#        '냉장고', '태블릿PC', '현관·신발정리', '고양이', '식기건조대', '청소세제·세정제', '단스탠드',
#        '책상', '냄비·프라이팬·솥', '캠핑가구', '가벽·파티션', '형광등·조명부속품', '블라인드·롤스크린',
#        '컴퓨터·노트북', '후크·수납걸이', '조리도구·도마', '화장대·테이블정리', '월데코·장식', 'TV',
#        'LED 등', '키친', '유아동가구', '시계', '욕실용품', '매트리스커버', '천장등', '주방용품',
#        '외출용품', 'DIY&리폼', '완구·교구', '서랍장·트롤리', 'DIY·취미·공예', '청소', '카메라',
#        '생수·음료·커피', '세탁용품', '의자·소파', 'O!STYLING', '세탁세제·유연제', '유아동패브릭',
#        '화장지·물티슈', '센서등', '가전패키지', '건축&주택', '가구부속품', '옷걸이', '세탁기·건조기',
#        '휴대폰', '모니터', '베이커리·떡', 'O!PLATING', '영상가전', '손잡이·방문·유리', '헤어케어',
#        '바닥재', '빨래바구니·햄퍼', '수입주방관', '주방세제', '공구', '패브릭', '공간별가구', '이미용가전',
#        '벽조명', '생필품', '타일·파벽돌', '침낭·매트·해먹', '수건·타월', '공간별주방용품', '소파·생활커버',
#        '베이킹용품', '접착제·보수용품', '제습·탈취·방향제', '근력', '이유식용품', '목재', '브랜드샵',
#        '칼·커팅기구', '가구·인테리어', '양치용품', '쿠션·방석', '수납·정리', '보호대', '유아·아동',
#        '캠핑주방용품', '주방', '간식·과자', '데스크스탠드', '캠핑생활용품', '밀키트', '조명',
#        '생활·주방가전', '데코·식물', '요가·스트레칭', '중문·도어', '페인트·부자재', '와인·칵테일용품',
#        '기저귀·기저귀용품', '분유·수유용품', '영상·음향·디지털', '이거어때', '유산소', '대형가전',
#        'Tidying up clothes, tidying up blankets', '에어컨', '복합기·프린터·스캐너',
#        '렌탈', '생활용품', '벽지·장판·마루', '욕실', '과일·정육', '기타실내운동용품',
#        'Chest of drawers and trolley', '홈케어', '면도용품', '공간별조명', '캠핑가전',
#        '유제품·아이스크림', 'Sofa living cover', '텐트·타프', '스마트워치·밴드', '필라테스',
#        '몰딩·걸레받이', '구강·위생용품', '가전·디지털', '이유·유아식기', '헬스·뷰티·안마·기타', '정수기',
#        '유아·아동식기', '관상어·소동물', '저장장치', '살충·방충제', '침구세트', '행거', '상업공간',
#        '빌트인수납', '厨房织物', '창호·폴딩도어', 'table, dining table, desk',
#        'Tigela, conjunto de casa', 'Cortinas materiales auxiliares', '비데',
#        'hanger', '小狗', 'drawers & cabinets', '반려동물', '플라워 식물', '캠핑부품·공구',
#        '반려동물(티모)', '유아용패브릭', 'dish drying rack', '생리대·성인기저귀', '건강식품',
#        '면·소스·조미료', '소파 거실가구', '생활', '기프트샵', '공기청정기', '수건 타월', '家具',
#        '침실가구', '캠핑용품', '공구·DIY', 'cuộc sống', '가전', '디지털가전', '서재 학생가구',
#        '실내운동', '홈데코', 'Kitchen storage and organization',
#        'Living room, TV cabinet', 'chair', 'Home Gallery', '鍋・フライパン・釜',
#        'camping kitchen utensils', 'Display case, bookshelf', '五斗櫃和手推車',
#        'life information', '(D2)A-미노출   B-노출', 'Furniture by space',
#        'Sofa', '인테리어시공', '音响设备', '화장대 거울', '情绪灯和装饰照明', 'lathe', '조리도구 도마',
#        '引き出し・収納棚', '室内道具', 'la télé', '청소가전', '그릇 홈세트', 'mirror',
#        'duvet, duvet', '枕・枕カバー', 'interior props', '单支架', 'long stand',
#        '墊子 安全用品', 'Витрина и книжная полка', '吸顶灯', 'кровать', '수납장 서랍장',
#        '식품', 'Hook Storage Hanger', '客廳、電視櫃', 'bed',
#        'Pişirme gereçleri, doğrama tahtası', '季节性电器',
#        'Storage container lunch', '보관 용기 도시락', '침구', '고양이 리빙',
#        'Multifunction device printer scanner', 'kitchen appliances',
#        'Tepper og tepper', '데스크 디자인문구', '书桌·设计文具', 'baby fabric', '生活情報',
#        '취미 DIY 파티', 'Living box basket', '沙发', '의자 스툴', 'Rugs & Carpets',
#        'cellular phone', 'ラグ・カーペット', 'is this', '桌子，餐桌，书桌', '吸塵器',
#        '후크 수납걸이', '椅子', 'cadeira', '카페트 러그', '기타인테리어시공', 'Ghế sô pha',
#        'Flower, plant', 'Coffee & Tea Supplies', 'thiết bị theo mùa',
#        'dressing table console', 'cái kệ', '清潔產品', '컵 잔 텀블러',
#        'Congelamento·Refrigeração·Alimentos de conveniência',
#        'camping furniture', 'tin kiến \u200b\u200bthức xây dựng',
#        'dish dryer', '花卉、植物', '手机', 'tool', '架子', 'shelf', 'mat', 'watch',
#        '식탁 테이블', '首页图库', 'Pot, frying pan, caldron', '沙發', '鏡', '手表',
#        '캔들 디퓨져', 'sound appliances', 'camping appliances', '垫', '아기물티슈',
#        'the couch', 'baby furniture', '聖誕節', '美髮器具', 'cell phone',
#        'Tuvalet masası ve masa düzeni', 'seasonal appliances', '체중계',
#        '수저 커트러리', 'ムード灯・装飾照明', '관상어', 'สินค้าเบ็ดเตล็ดในครัว',
#        'Mat Safety Goods', '單支架', 'tiroirs et armoires', '生活箱 篮',
#        'hairdressing appliances', 'Sound appliances',
#        'kitchen miscellaneous goods', 'Living, health appliances',
#        '水果和肉类', '衣架，壁橱', 'Showcase & Bookshelf', '드레스룸', 'towels, towels',
#        'แกลเลอรีหน้าแรก', 'wall deco decoration', '地毯和地毯',
#        'Mattress Topper', 'bedding set',
#        'Архитектура и жилищное строительство', 'Cutlery & Cutlery', '镜子',
#        'storage device', 'Curtains subsidiary materials', '配菜、酱料',
#        'Duvet & Duvet', '存储 容器 午餐', 'Lighting by space',
#        'bathroom supplies', '酒类·鸡尾酒用品', 'desk stand', 'لوازم صوتی',
#        'monitor', 'hanger, closet', 'çekmeceler ve dolaplar', 'fabric',
#        '캔들·디퓨저', '玩具、教具', '梳妆台和餐桌布置', 'Aperitivos Dulces', '수납가구',
#        'computer laptop', 'ban nhạc đồng hồ thông minh', '厨房杂货',
#        '고양이 위생 배변', 'Tidying clothes, tidying up blankets', '头发护理',
#        '리빙박스 수납함', 'construction information', 'подушка, подушка',
#        'タオル・タオル', 'estante', 'tent and tarp', 'вешалка, шкаф',
#        'Game machine, drone', '窗帘 辅助材料', '바구니 바스켓',
#        'Cooking utensils, chopping board', '厨房存储和组织', '玄関・靴整理', 'LED 燈',
#        'cama', 'เครื่องใช้ในครัว', 'home fabric', '有酸素', '주방가구',
#        '洗衣機和烘乾機', 'bardak, kadeh, bardak', 'Cleaning detergent detergent',
#        'جارو برقی', '床墊套', 'компьютер и ноутбук', '杯、高脚杯、不倒翁',
#        'cup, goblet, tumbler', '织物', 'Casserole, poêle, chaudron',
#        'Christmas', '食器乾燥機', 'เครื่องใช้ในบ้านวิดีโอ', 'vacuum cleaner',
#        'Arquitectura y Vivienda', '生活資訊', 'cleaning supplies', '扩香蜡烛',
#        'Свет настроения и декоративное освещение', 'storage closet',
#        'Decor Plant', 'laci & lemari', '床', '碗碟晾衣架', 'リビングボックス・バスケット',
#        '음향 영상가전', '露营家具', 'bulaşık kurutma rafı',
#        'Eau minérale, boisson, café', 'Chest of drawers, trolley',
#        '현관 신발정리', 'chaise', 'Table, dining table, desk', '锅，煎锅，大锅',
#        'Life & Health Appliances', 'rug caffet', '桌子，餐桌，辦公桌',
#        'baking supplies', 'Topper Pad', 'Toys, teaching aids',
#        'Kahve ve Çay Malzemeleri', 'wood', 'ショーケース・本棚',
#        'gantungan, lemari', '碗，家用套裝', 'ceiling lamp', 'cushion, cushion',
#        'flor, planta', 'цветок, растение', 'เทศกาลคริสต์มาส',
#        'LED lights', 'Electric', 'inredningstips', 'κρεβάτι', 'raf',
#        'LED灯', 'table, table à manger, bureau', 'سرير', 'Plafonnier',
#        'умный ремешок для часов', 'LED Light', 'Bát, bộ nhà',
#        'kitchen fabric', 'Chest of drawers and trolley ',
#        'Сотовый телефон', 'single stand', '空间家具', '空间照明', '生活箱 籃',
#        'máy tính máy tính xách tay', 'Товары для жизни и здоровья',
#        'Bowl, home set', 'Entrance shoe cleaning', '储备',
#        'Dressing table and table arrangement', 'καρέκλα', 'bộ đồ giường',
#        '洗衣篮 篮', '生活、健康家电', '壁灯', 'Nồi, chảo, chảo', '空間別家具',
#        '洗濯バスケット・ハンパー', 'mattress cover', 'Desk·Design stationery',
#        'Armazenamento, recipiente, lancheira', 'カップ, グラス, タンブラー',
#        'Lanches Doces', 'ソファ', '공예 취미', '鏡子', '坐墊，坐墊', '荧光灯和照明配件',
#        'infant child', '首頁圖庫', 'Кастрюля, сковорода, котел', '床上用品',
#        'Laundry detergent and softener', 'Collations bonbons', '신혼소품',
#        'Pillows and pillow covers', 'oshxona jihozlari', 'โทรศัพท์มือถือ',
#        'diffuser candle', 'cleaning products', 'duvar ışığı',
#        'kit refeição', 'Architecture & Housing', '학생 서재가구', '抽屜櫃',
#        'camping supplies', 'ของเล่นสื่อการสอน', '陈列柜和书架', 'stage stand',
#        'DIY & Reformasi', '棚', 'Mood light and decorative lighting',
#        'furniture', '厨房电器', 'video home appliances',
#        'Çatal bıçak takımı ve çatal bıçak takımı', 'ダンスタンド',
#        'Lưu trữ   container   bữa trưa', '頂墊', 'appareils de cuisine',
#        '廚房存儲和組織', '炊具、砧板', 'Diffuser Candle', 'Tencere, tava, kazan',
#        'Bakery, rice cake', 'cabide, armário', 'bowl and home set',
#        'mutfak kumaşı', '存儲、組織', '五斗柜和手推车', 'ลิ้นชักและตู้', '乳制品和冰淇淋',
#        '생활가전', 'لوازم آرایشگری', 'Kerstmis', 'Диффузорная свеча ',
#        '刀具和切割工具', '刀叉餐具', '露营用品', 'Home Appliances Digital', '擴香蠟燭',
#        'Письменный стол · Дизайнерские канцтовары', 'Nệm topper',
#        '冷冻·冷藏·方便食品', 'カップ・寝た・タンブラー', '提示', 'the bed', '桌子，餐桌，办公桌',
#        'rugs and carpets', 'elektrikli süpürge', 'laundry supplies',
#        'furniture accessories', '洗衣机和烘干机', '生活资讯', '吸尘器', 'Рождество',
#        'hoa, cây', '圣诞节', '家庭用品', '커피 티용품', 'Cup, glass, tumbler',
#        '고양이 패션 외출', 'リビングボックスバスケット', '布団・布団', '入口 鞋子清洁', 'DIY & Reform',
#        '清洁用品', '器・ホムセトゥ', 'sofa', 'クッション・クッション', 'ディフューザー・キャンドル',
#        'wall partition', '化粧台・コンソール', 'Mattress Cover', 'mutfak aletleri',
#        '커튼 블라인드', 'tempat tidur', '碗，家用套装', '布団・布団 ',
#        'Fırın, pirinç keki', 'συρτάρια & ντουλάπια', 'aerobic',
#        'Kilimler ve Halılar', 'recuzită interioară',
#        'Fluorescent lamps and lighting accessories',
#        'produits divers de cuisine', 'ceiling light',
#        'Bàn, bàn ăn, bàn làm việc', 'Cushion, cushion',
#        'DIY, hobbies, crafts', 'Hanger', 'одиночная стойка', '陳列櫃和書架',
#        '露营厨房用具', '수입주방용품', 'マット', '皮肤护理', 'lave-linge et sèche-linge',
#        'LED燈', 'desk', '引き出し・収納場', 'Dao kéo dao kéo', '面条、酱汁、调味料',
#        'ผ้าม่าน วัสดุย่อย', 'Storage, organization', '洗衣液和柔顺剂', 'LED평판등',
#        'Materac nawierzchniowy', 'coffee and tea supplies', 'ดอกไม้พืช',
#        '家庭键盘', 'Đèn tường', '客厅、电视柜', 'air conditioner', '机',
#        'สินค้าใช้ในบ้าน', '卫浴用品', '냄비 프라이팬', '羽絨被和羽絨被',
#        'Couverts et couverts', 'Drawer, cabinet',
#        'Ustensiles de cuisine, planche à découper', 'Tool, DIY',
#        'DIY・趣味・工芸', 'más limpio', '書桌·設計文具', 'tissu de cuisine',
#        'Depolama, konteyner, beslenme çantası', 'Nhà bếp', 'ボウル・ホームセット',
#        'yatak', 'móc áo, tủ quần áo', 'マットレスカバー', '视频家电', '収納状・ワードローブ',
#        '벽지 시트지', '抽屉柜', '照明', 'łóżko', 'Sala de estar, armário de tv',
#        'موقف واحد', 'Chinese door', '殺虫・防虫剤', '季節性電器', 'Danstand',
#        'Knives and cutting tools', 'жизни',
#        'Entrance hall, shoe arrangement', 'Organize storage by space',
#        'คอมพิวเตอร์ แล็ปท็อป', 'คริสต์มาส', '美发器具',
#        'tasse, gobelet, gobelet', '长期立场', '織物', 'refrigerator',
#        'yatak örtüsü', 'brand shop', 'Tapetes e Carpetes',
#        'Panci, penggorengan, kuali', 'テーブル・食卓・机', 'Диффузорная свеча',
#        'Pillow, pillowcase', '廚房雜貨', 'クリーナー', 'Deskstand', '羽绒被和羽绒被',
#        'Trang trí Thực vật', 'Pot·frying pan·dron', '墙面装饰'], dtype=object)

# %%
sparse_matrix = train_df.groupby('category2').apply(lambda x: pd.Series(x['rating'].values, index=x['uid'])).unstack()
sparse_matrix.index.name = 'category2'

sparse_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11740\3890113126.py in <module>
# ----> 1 sparse_matrix = train_df.groupby('category2').apply(lambda x: pd.Series(x['rating'].values, index=x['uid'])).unstack()
#       2 sparse_matrix.index.name = 'category2'
#       3
#       4 sparse_matrix
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    4155         from pandas.core.reshape.reshape import unstack
#    4156
# -> 4157         return unstack(self, level, fill_value)
#    4158
#    4159     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     489         if is_1d_only_ea_dtype(obj.dtype):
#     490             return _unstack_extension_series(obj, level, fill_value)
# --> 491         unstacker = _Unstacker(
#     492             obj.index, level=level, constructor=obj._constructor_expanddim
#     493         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     138             )
#     139
# --> 140         self._make_selectors()
#     141
#     142     @cache_readonly
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     190
#     191         if mask.sum() < len(self.index):
# --> 192             raise ValueError("Index contains duplicate entries, cannot reshape")
#     193
#     194         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape
