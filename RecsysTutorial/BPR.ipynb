# %% [markdown]
# - GMF를 가지고 비교
# - 메트릭은 NDCG, HIT 사용
# - 동일한 Weight, 배치마다 동일한 데이터셋으로 비교
# - E-commerce_Data 적용

# %%
import random
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

import warnings
from tqdm import tqdm

from box import Box

warnings.filterwarnings(action='ignore')

# %%
data_dir = '../RecsysTutorial/files/'
model_dir = '../RecsysTutorial/model/'

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)

# %%
config = {
    'top_k' : 10,
    'epochs' : 50,
    'lr' : 1e-03,
    'batch_size' : 256,

    'num_factor' :64,
    "reg" : 1e-5,
    'neg_samples' : 3,
}

config = Box(config)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
class MakeDataset():
    def __init__(self, config, df : pd.DataFrame):
        self.config = config
        self.df = df
        self.user_encoder, self.user_decoder, self.item_encoder, self.item_decoder = self.get_encoder_decoder()
        self.num_users = len(self.user_encoder)
        self.num_items = len(self.item_encoder)
        self.all_items = [i for i in range(self.num_items)]

        self.df['user_no'] = self.df['user_no'].apply(lambda x : self.user_encoder[x])
        self.df['item_no'] = self.df['item_no'].apply(lambda x : self.item_encoder[x])
        self.user_neg_candidate = self.get_user_neg_candidate()

        self.train_set_user, self.train_set_item, self.train_set_target, self.test_set_user, self.test_set_item, self.test_set_target = self.train_test_data_split()

    def train_test_data_split(self):

        user_no_li = self.df['user_no'].unique()

        train_set_item = []
        train_set_user = []
        train_set_target = []

        test_set_item = []
        test_set_user = []
        test_set_target = []

        for user_no in user_no_li:
            user_df = self.df[self.df['user_no'] == user_no].sort_values('event_timestamp')
            item_no_li = user_df['item_no'].tolist()
            
            train_item = item_no_li[:-1]
            train_user = [user_no] * len(train_item)
            train_target = [1] * len(train_item)

            test_itme = [item_no_li[-1]] + np.random.choice(self.user_neg_candidate[user_no], 99, replace = False).tolist()
            test_user = [user_no] * len(test_itme)
            test_target = [1] + [0] * (len(test_itme) - 1)

            train_set_item += train_item
            train_set_user += train_user
            train_set_target += train_target

            test_set_item += test_itme
            test_set_user += test_user
            test_set_target += test_target

        return train_set_user, train_set_item, train_set_target, test_set_user, test_set_item, test_set_target

    def get_neg_samples(self, n : int, user_no_li):
        neg_samples_user = []
        neg_samples_item = []
        for u in user_no_li:
            u_neg_candidate = self.user_neg_candidate[u]
            for _ in range(n):
                neg_samples_item.append(u_neg_candidate[np.random.randint(len(u_neg_candidate))])
                neg_samples_user.append(u)

        return neg_samples_user, neg_samples_item

    def get_user_neg_candidate(self):
        user_candidate = {}
        for user_no in self.df['user_no'].unique():
            item_no_li = self.df[self.df['user_no'] == user_no]['item_no'].tolist()
            item_no_li = [item_no for item_no in item_no_li]
            user_candidate[user_no] = list(set(self.all_items) - set(item_no_li))
        
        return user_candidate

    def get_encoder_decoder(self):
        user_encoder, user_decoder = {}, {}
        for idx, user_no in enumerate(self.df['user_no'].unique()):
            user_encoder[user_no] = idx
            user_decoder[idx] = user_no

        item_encoder, item_decoder = {}, {}
        for idx, item_id in enumerate(self.df['item_no'].unique()):
            item_encoder[item_id] = idx
            item_decoder[idx] = item_id
        
        return user_encoder, user_decoder, item_encoder, item_decoder
    
    def get_data(self, train : bool = True):
        if train: return self.train_set_user, self.train_set_item, self.train_set_target
        else: return self.test_set_user, self.test_set_item, self.test_set_target

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

class CustomDataset(Dataset):
    def __init__(self, set_user : list, set_item : list, set_target : list):
        self.set_user = set_user
        self.set_item = set_item
        self.set_target = set_target

    def __len__(self):
        return len(self.set_user)

    def __getitem__(self, idx):
        user = self.set_user[idx]
        item = self.set_item[idx]
        target = self.set_target[idx]

        return user, item, target

# %%
class GMF(nn.Module):
    def __init__(self, num_user, num_item, num_factor):
        super(GMF, self).__init__()
        self.user_emb = nn.Embedding(num_user, num_factor)
        self.item_emb = nn.Embedding(num_item, num_factor)
        
        self.predict_layer = nn.Sequential(
            nn.Linear(num_factor, 1, bias = False)
        )

        self._init_weight_()
    
    def _init_weight_(self):
        nn.init.normal_(self.user_emb.weight, std=0.01)
        nn.init.normal_(self.item_emb.weight, std=0.01)
        for m in self.predict_layer:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_uniform_(m.weight, a=1, nonlinearity="sigmoid")
    
    def forward(self, user, item):
        user_emb = self.user_emb(user)
        item_emb = self.item_emb(item)

        output = self.predict_layer(user_emb * item_emb)

        return output.view(-1)

# %%
def hit(target_item, pred_items):
    if target_item in pred_items:
        return 1
    return 0

def ndcg(target_item, pred_items):
    if target_item in pred_items:
        idx = pred_items.index(target_item)
        # 초기 인덱스가 0이기 때문에 +2 함
        return np.reciprocal(np.log2(idx + 2))
    return 0

def metrics(model, test_loader, top_k):
    model.eval()
    HR, NDCG = [], []
    with torch.no_grad():
        for user, item, _ in test_loader:
            user = user.to(device)
            item = item.to(device)

            predictions = model(user, item)
            # 가장 높은 top_k개 선택
            _, indices = torch.topk(predictions, top_k)
            # 해당 상품 index 선택
            recommends = torch.take(item, indices).cpu().numpy().tolist()
            # 정답값 선택
            target_item = item[0].item()
            HR.append(hit(target_item, recommends))
            NDCG.append(ndcg(target_item, recommends))

    return np.mean(HR), np.mean(NDCG)

# %%
class BPR_Loss(nn.Module):
    def __init__(self):
        super(BPR_Loss, self).__init__()
    
    def forward(self, pos, neg):
        bpr_loss = -torch.mean(torch.log(torch.sigmoid(pos - neg)))
        return bpr_loss

# %%
ratings_df = pd.read_csv(data_dir + 'sample_df.csv')

dataset = MakeDataset(config = config, df = ratings_df)

train_set_user, train_set_item, train_set_target = dataset.get_data(train = True)
train_dataset = CustomDataset(set_user = train_set_user, set_item = train_set_item, set_target = train_set_target)
train_loader = DataLoader(train_dataset, batch_size = config.batch_size, shuffle = True, drop_last = False)

test_set_user, test_set_item, test_set_target = dataset.get_data(train = False)
test_dataset = CustomDataset(set_user = test_set_user, set_item = test_set_item, set_target = test_set_target)
test_loader = DataLoader(test_dataset, batch_size = 100, shuffle = False, drop_last = False)

# %%
import copy
# 동일한 Weight에서 초기화 시키기 위해서 copy 사용

gmf = GMF(num_user = dataset.num_users, num_item = dataset.num_items, num_factor = config.num_factor)
model = copy.deepcopy(gmf).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = config.lr)
loss_func = nn.BCELoss()

bpr_model = copy.deepcopy(gmf).to(device)
bpr_optimizer = torch.optim.Adam(bpr_model.parameters(), lr = config.lr)
bpr_loss_func = BPR_Loss()

# %%
non_bpr_model_loss_list = []
non_bpr_model_hr_list = []
non_bpr_model_ndcg_list = []

bpr_model_loss_list = []
bpr_model_hr_list = []
bpr_model_ndcg_list = []

best_metric = 0
bpr_best_metric = 0

for epoch in range(1, config.epochs + 1):
    # 학습
    model.train()
    bpr_model.train()

    train_loss = 0
    bpr_train_loss = 0

    for user, item, target in train_loader:
        # neg_sampling
        neg_user, neg_item = dataset.get_neg_samples(n = config.neg_samples, user_no_li = user.numpy().tolist())
        neg_target = [0] * len(neg_item)

        user, item, target = user.to(device), item.to(device), target.to(device).float()
        neg_user, neg_item, neg_target = torch.tensor(neg_user).to(device), torch.tensor(neg_item).to(device), torch.tensor(neg_target).to(device).float()

        all_user = torch.concat([user, torch.tensor(neg_user)])
        all_item = torch.concat([item, torch.tensor(neg_item)])
        all_target = torch.concat([target, torch.tensor(neg_target)])

        # BPR X 모델 학습
        optimizer.zero_grad()
        output = model(all_user, all_item)
        loss = loss_func(torch.sigmoid(output), all_target)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        # BPR O 모델 학습
        bpr_optimizer.zero_grad()
        output = bpr_model(all_user, all_item)
        pos_output, neg_output = torch.split(output, [len(user), len(neg_user)])
        pos_output = torch.concat([pos_output.view(-1, 1), pos_output.view(-1, 1), pos_output.view(-1, 1)], dim = 1).view(-1)

        loss = bpr_loss_func(pos_output, neg_output)

        loss.backward()
        bpr_optimizer.step()

        bpr_train_loss += loss.item()

    train_loss /= len(train_loader)
    bpr_train_loss /= len(train_loader)

    # 평가
    non_bpr_model_hr, non_bpr_model_ndcg = metrics(model = model, test_loader = test_loader, top_k = config.top_k)
    bpr_model_hr, bpr_model_ndcg = metrics(model = bpr_model, test_loader = test_loader, top_k = config.top_k)

    print(f"[EPOCH: {epoch}]")
    print(f"Non-BPR-GMF Train Loss: {train_loss:.4f}, HR: {non_bpr_model_hr:.4f}, NDCG: {non_bpr_model_ndcg:.4f}")
    print(f"BPR-GMF Train Loss: {bpr_train_loss:.4f}, HR: {bpr_model_hr:.4f}, NDCG: {bpr_model_ndcg:.4f}\n")

    non_bpr_model_loss_list.append(train_loss)
    non_bpr_model_hr_list.append(non_bpr_model_hr)
    non_bpr_model_ndcg_list.append(non_bpr_model_ndcg)

    bpr_model_loss_list.append(bpr_train_loss)
    bpr_model_hr_list.append(bpr_model_hr)
    bpr_model_ndcg_list.append(bpr_model_ndcg)

    if best_metric < non_bpr_model_hr:
        best_metric = non_bpr_model_hr
        torch.save(model.state_dict(), model_dir + f'Non-BPR-GMF.pt')

    if bpr_best_metric < bpr_model_ndcg:
        bpr_best_metric = bpr_model_ndcg
        torch.save(bpr_model.state_dict(), model_dir + f'BPR-GMF.pt')
# Out:
# [EPOCH: 1]
# Non-BPR-GMF Train Loss: 0.6931, HR: 0.1045, NDCG: 0.0491
# BPR-GMF Train Loss: 0.6931, HR: 0.1044, NDCG: 0.0503
#
# [EPOCH: 2]
# Non-BPR-GMF Train Loss: 0.6931, HR: 0.1104, NDCG: 0.0542
# BPR-GMF Train Loss: 0.6926, HR: 0.1108, NDCG: 0.0547
#
# [EPOCH: 3]
# Non-BPR-GMF Train Loss: 0.6926, HR: 0.1115, NDCG: 0.0554
# BPR-GMF Train Loss: 0.6888, HR: 0.1116, NDCG: 0.0566
#
# [EPOCH: 4]
# Non-BPR-GMF Train Loss: 0.6909, HR: 0.1111, NDCG: 0.0567
# BPR-GMF Train Loss: 0.6737, HR: 0.1117, NDCG: 0.0578
#
# [EPOCH: 5]
# Non-BPR-GMF Train Loss: 0.6868, HR: 0.1135, NDCG: 0.0587
# BPR-GMF Train Loss: 0.6367, HR: 0.1114, NDCG: 0.0585
#
# [EPOCH: 6]
# Non-BPR-GMF Train Loss: 0.6788, HR: 0.1137, NDCG: 0.0595
# BPR-GMF Train Loss: 0.5712, HR: 0.1102, NDCG: 0.0584
#
# [EPOCH: 7]
# Non-BPR-GMF Train Loss: 0.6668, HR: 0.1146, NDCG: 0.0602
# BPR-GMF Train Loss: 0.4811, HR: 0.1101, NDCG: 0.0585
#
# [EPOCH: 8]
# Non-BPR-GMF Train Loss: 0.6514, HR: 0.1139, NDCG: 0.0600
# BPR-GMF Train Loss: 0.3810, HR: 0.1107, NDCG: 0.0585
#
# [EPOCH: 9]
# Non-BPR-GMF Train Loss: 0.6342, HR: 0.1151, NDCG: 0.0605
# BPR-GMF Train Loss: 0.2883, HR: 0.1092, NDCG: 0.0579
#
# [EPOCH: 10]
# Non-BPR-GMF Train Loss: 0.6171, HR: 0.1153, NDCG: 0.0607
# BPR-GMF Train Loss: 0.2120, HR: 0.1079, NDCG: 0.0573
#
# [EPOCH: 11]
# Non-BPR-GMF Train Loss: 0.6013, HR: 0.1158, NDCG: 0.0610
# BPR-GMF Train Loss: 0.1549, HR: 0.1074, NDCG: 0.0569
#
# [EPOCH: 12]
# Non-BPR-GMF Train Loss: 0.5870, HR: 0.1157, NDCG: 0.0608
# BPR-GMF Train Loss: 0.1137, HR: 0.1068, NDCG: 0.0566
#
# [EPOCH: 13]
# Non-BPR-GMF Train Loss: 0.5734, HR: 0.1156, NDCG: 0.0608
# BPR-GMF Train Loss: 0.0844, HR: 0.1068, NDCG: 0.0563
#
# [EPOCH: 14]
# Non-BPR-GMF Train Loss: 0.5600, HR: 0.1152, NDCG: 0.0606
# BPR-GMF Train Loss: 0.0636, HR: 0.1062, NDCG: 0.0560
#
# [EPOCH: 15]
# Non-BPR-GMF Train Loss: 0.5464, HR: 0.1148, NDCG: 0.0604
# BPR-GMF Train Loss: 0.0490, HR: 0.1064, NDCG: 0.0559
#
# [EPOCH: 16]
# Non-BPR-GMF Train Loss: 0.5298, HR: 0.1137, NDCG: 0.0602
# BPR-GMF Train Loss: 0.0383, HR: 0.1063, NDCG: 0.0559
#
# [EPOCH: 17]
# Non-BPR-GMF Train Loss: 0.5112, HR: 0.1145, NDCG: 0.0603
# BPR-GMF Train Loss: 0.0307, HR: 0.1060, NDCG: 0.0557
#
# [EPOCH: 18]
# Non-BPR-GMF Train Loss: 0.4880, HR: 0.1140, NDCG: 0.0599
# BPR-GMF Train Loss: 0.0250, HR: 0.1058, NDCG: 0.0555
#
# [EPOCH: 19]
# Non-BPR-GMF Train Loss: 0.4594, HR: 0.1138, NDCG: 0.0600
# BPR-GMF Train Loss: 0.0206, HR: 0.1057, NDCG: 0.0554
#
# [EPOCH: 20]
# Non-BPR-GMF Train Loss: 0.4264, HR: 0.1147, NDCG: 0.0604
# BPR-GMF Train Loss: 0.0173, HR: 0.1055, NDCG: 0.0553
#
# [EPOCH: 21]
# Non-BPR-GMF Train Loss: 0.3883, HR: 0.1146, NDCG: 0.0604
# BPR-GMF Train Loss: 0.0146, HR: 0.1055, NDCG: 0.0552
#
# [EPOCH: 22]
# Non-BPR-GMF Train Loss: 0.3480, HR: 0.1144, NDCG: 0.0603
# BPR-GMF Train Loss: 0.0125, HR: 0.1055, NDCG: 0.0552
#
# [EPOCH: 23]
# Non-BPR-GMF Train Loss: 0.3062, HR: 0.1130, NDCG: 0.0599
# BPR-GMF Train Loss: 0.0107, HR: 0.1052, NDCG: 0.0550
#
# [EPOCH: 24]
# Non-BPR-GMF Train Loss: 0.2665, HR: 0.1134, NDCG: 0.0598
# BPR-GMF Train Loss: 0.0094, HR: 0.1052, NDCG: 0.0549
#
# [EPOCH: 25]
# Non-BPR-GMF Train Loss: 0.2299, HR: 0.1132, NDCG: 0.0599
# BPR-GMF Train Loss: 0.0082, HR: 0.1048, NDCG: 0.0547
#
# [EPOCH: 26]
# Non-BPR-GMF Train Loss: 0.1986, HR: 0.1126, NDCG: 0.0595
# BPR-GMF Train Loss: 0.0072, HR: 0.1047, NDCG: 0.0547
#
# [EPOCH: 27]
# Non-BPR-GMF Train Loss: 0.1707, HR: 0.1121, NDCG: 0.0593
# BPR-GMF Train Loss: 0.0064, HR: 0.1047, NDCG: 0.0547
#
# [EPOCH: 28]
# Non-BPR-GMF Train Loss: 0.1470, HR: 0.1117, NDCG: 0.0591
# BPR-GMF Train Loss: 0.0057, HR: 0.1047, NDCG: 0.0547
#
# [EPOCH: 29]
# Non-BPR-GMF Train Loss: 0.1277, HR: 0.1117, NDCG: 0.0590
# BPR-GMF Train Loss: 0.0051, HR: 0.1049, NDCG: 0.0547
#
# [EPOCH: 30]
# Non-BPR-GMF Train Loss: 0.1108, HR: 0.1119, NDCG: 0.0588
# BPR-GMF Train Loss: 0.0046, HR: 0.1046, NDCG: 0.0545
#
# [EPOCH: 31]
# Non-BPR-GMF Train Loss: 0.0971, HR: 0.1108, NDCG: 0.0580
# BPR-GMF Train Loss: 0.0042, HR: 0.1045, NDCG: 0.0545
#
# [EPOCH: 32]
# Non-BPR-GMF Train Loss: 0.0851, HR: 0.1093, NDCG: 0.0574
# BPR-GMF Train Loss: 0.0038, HR: 0.1041, NDCG: 0.0544
#
# [EPOCH: 33]
# Non-BPR-GMF Train Loss: 0.0754, HR: 0.1098, NDCG: 0.0573
# BPR-GMF Train Loss: 0.0035, HR: 0.1040, NDCG: 0.0543
#
# [EPOCH: 34]
# Non-BPR-GMF Train Loss: 0.0665, HR: 0.1088, NDCG: 0.0568
# BPR-GMF Train Loss: 0.0031, HR: 0.1038, NDCG: 0.0542
#
# [EPOCH: 35]
# Non-BPR-GMF Train Loss: 0.0593, HR: 0.1087, NDCG: 0.0567
# BPR-GMF Train Loss: 0.0029, HR: 0.1040, NDCG: 0.0542
#
# [EPOCH: 36]
# Non-BPR-GMF Train Loss: 0.0528, HR: 0.1090, NDCG: 0.0568
# BPR-GMF Train Loss: 0.0026, HR: 0.1038, NDCG: 0.0542
#
# [EPOCH: 37]
# Non-BPR-GMF Train Loss: 0.0474, HR: 0.1076, NDCG: 0.0564
# BPR-GMF Train Loss: 0.0024, HR: 0.1038, NDCG: 0.0541
#
# [EPOCH: 38]
# Non-BPR-GMF Train Loss: 0.0428, HR: 0.1072, NDCG: 0.0561
# BPR-GMF Train Loss: 0.0022, HR: 0.1037, NDCG: 0.0540
#
# [EPOCH: 39]
# Non-BPR-GMF Train Loss: 0.0387, HR: 0.1077, NDCG: 0.0562
# BPR-GMF Train Loss: 0.0021, HR: 0.1037, NDCG: 0.0540
#
# [EPOCH: 40]
# Non-BPR-GMF Train Loss: 0.0350, HR: 0.1078, NDCG: 0.0560
# BPR-GMF Train Loss: 0.0019, HR: 0.1035, NDCG: 0.0539
#
# [EPOCH: 41]
# Non-BPR-GMF Train Loss: 0.0319, HR: 0.1077, NDCG: 0.0560
# BPR-GMF Train Loss: 0.0018, HR: 0.1035, NDCG: 0.0539
#
# [EPOCH: 42]
# Non-BPR-GMF Train Loss: 0.0290, HR: 0.1073, NDCG: 0.0558
# BPR-GMF Train Loss: 0.0016, HR: 0.1034, NDCG: 0.0539
#
# [EPOCH: 43]
# Non-BPR-GMF Train Loss: 0.0265, HR: 0.1072, NDCG: 0.0556
# BPR-GMF Train Loss: 0.0015, HR: 0.1034, NDCG: 0.0538
#
# [EPOCH: 44]
# Non-BPR-GMF Train Loss: 0.0242, HR: 0.1062, NDCG: 0.0552
# BPR-GMF Train Loss: 0.0014, HR: 0.1035, NDCG: 0.0538
#
# [EPOCH: 45]
# Non-BPR-GMF Train Loss: 0.0224, HR: 0.1067, NDCG: 0.0552
# BPR-GMF Train Loss: 0.0013, HR: 0.1033, NDCG: 0.0538
#
# [EPOCH: 46]
# Non-BPR-GMF Train Loss: 0.0206, HR: 0.1065, NDCG: 0.0551
# BPR-GMF Train Loss: 0.0012, HR: 0.1036, NDCG: 0.0539
#
# [EPOCH: 47]
# Non-BPR-GMF Train Loss: 0.0189, HR: 0.1064, NDCG: 0.0550
# BPR-GMF Train Loss: 0.0012, HR: 0.1037, NDCG: 0.0539
#
# [EPOCH: 48]
# Non-BPR-GMF Train Loss: 0.0174, HR: 0.1060, NDCG: 0.0549
# BPR-GMF Train Loss: 0.0011, HR: 0.1036, NDCG: 0.0538
#
# [EPOCH: 49]
# Non-BPR-GMF Train Loss: 0.0162, HR: 0.1061, NDCG: 0.0550
# BPR-GMF Train Loss: 0.0010, HR: 0.1034, NDCG: 0.0538
#
# [EPOCH: 50]
# Non-BPR-GMF Train Loss: 0.0150, HR: 0.1059, NDCG: 0.0549
# BPR-GMF Train Loss: 0.0009, HR: 0.1032, NDCG: 0.0537

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 3, figsize = (15, 5))
ax = ax.flatten()
epochs = [i for i in range(1, config.epochs + 1)]

ax[0].plot(epochs, bpr_model_loss_list, label = 'BPR')
ax[0].plot(epochs, non_bpr_model_loss_list, label = 'Non-BPR')
ax[0].set_title('Loss')
ax[0].legend()

ax[1].plot(epochs, bpr_model_hr_list, label = 'BPR')
ax[1].plot(epochs, non_bpr_model_hr_list, label = 'Non-BPR')
ax[1].set_title('HR')
ax[1].legend()

ax[2].plot(epochs, bpr_model_ndcg_list, label = 'BPR')
ax[2].plot(epochs, non_bpr_model_ndcg_list, label = 'Non-BPR')
ax[2].set_title('NDCG')
ax[2].legend()
plt.show()
